# %%
import numpy as np

# %%
# My candy list
candies = ["Choclate","Gummy","Lollypop","Mint","Caramel"]
print("Original candies:", candies)

# pick 3 candies randomly (with replacement)
sample = np.random.choice(candies, size=3, replace=True)
print("Random sample:", sample)
# Out:
# Original candies: ['Choclate', 'Gummy', 'Lollypop', 'Mint', 'Caramel']
# Random sample: ['Choclate' 'Choclate' 'Gummy']
