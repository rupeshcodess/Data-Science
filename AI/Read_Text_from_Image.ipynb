# %%
# %pip install textract
# Out:
# Collecting textract
#   Downloading textract-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from textract) (11.3.0)
# Collecting speechrecognition>=3.8.1 (from textract)
#   Downloading speechrecognition-3.16.1-py3-none-any.whl.metadata (28 kB)
# Collecting argcomplete>=3.6.3 (from textract)
#   Downloading argcomplete-3.6.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from textract) (4.13.5)
# Requirement already satisfied: lxml>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from textract) (6.1.1)
# Requirement already satisfied: chardet>=5.2.0 in /usr/local/lib/python3.12/dist-packages (from textract) (5.2.0)
# Collecting docx2txt>=0.8 (from textract)
#   Downloading docx2txt-0.9-py3-none-any.whl.metadata (529 bytes)
# Collecting extract-msg>=0.40.0 (from textract)
#   Downloading extract_msg-0.55.0-py3-none-any.whl.metadata (15 kB)
# Collecting pdfminer-six>=20221105 (from textract)
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting python-pptx>=0.6.18 (from textract)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting xlrd<2.0.0,>=1.2.0 (from textract)
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.8.0->textract) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.8.0->textract) (4.15.0)
# Collecting olefile==0.47 (from extract-msg>=0.40.0->textract)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: tzlocal<6,>=4.2 in /usr/local/lib/python3.12/dist-packages (from extract-msg>=0.40.0->textract) (5.3.1)
# Collecting compressed-rtf<2,>=1.0.6 (from extract-msg>=0.40.0->textract)
#   Downloading compressed_rtf-1.0.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting ebcdic<2,>=1.1.1 (from extract-msg>=0.40.0->textract)
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting RTFDE<0.2,>=0.1.1 (from extract-msg>=0.40.0->textract)
#   Downloading rtfde-0.1.2.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting red-black-tree-mod<=1.23,>=1.20 (from extract-msg>=0.40.0->textract)
#   Downloading red-black-tree-mod-1.22.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20221105->textract) (3.4.7)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20221105->textract) (48.0.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx>=0.6.18->textract)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20221105->textract) (2.0.0)
# Requirement already satisfied: lark~=1.3.0 in /usr/local/lib/python3.12/dist-packages (from RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (1.3.1)
# Collecting oletools>=0.56 (from RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract)
#   Downloading oletools-0.60.2-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six>=20221105->textract) (3.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract) (3.3.2)
# Collecting easygui (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract)
#   Downloading easygui-0.98.3-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting colorclass (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract)
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pcodedmp>=1.2.5 (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract)
#   Downloading pcodedmp-1.2.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting msoffcrypto-tool (from oletools>=0.56->RTFDE<0.2,>=0.1.1->extract-msg>=0.40.0->textract)
#   Downloading msoffcrypto_tool-6.0.0-py3-none-any.whl.metadata (10 kB)
# Downloading textract-2.0.0-py3-none-any.whl (25 kB)
# Downloading argcomplete-3.6.3-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.3 MB/s eta 0:00:00
# Downloading docx2txt-0.9-py3-none-any.whl (4.0 kB)
# Downloading extract_msg-0.55.0-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.0/336.0 kB 10.8 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.2 MB/s eta 0:00:00
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 82.9 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 29.5 MB/s eta 0:00:00
# Downloading speechrecognition-3.16.1-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 59.2 MB/s eta 0:00:00
# Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 7.9 MB/s eta 0:00:00
# Downloading compressed_rtf-1.0.7-py3-none-any.whl (8.0 kB)
# Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 12.0 MB/s eta 0:00:00
# Downloading rtfde-0.1.2.2-py3-none-any.whl (36 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 11.8 MB/s eta 0:00:00
# Downloading oletools-0.60.2-py2.py3-none-any.whl (989 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.4/989.4 kB 55.9 MB/s eta 0:00:00
# Downloading pcodedmp-1.2.6-py2.py3-none-any.whl (30 kB)
# Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Downloading easygui-0.98.3-py2.py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 7.9 MB/s eta 0:00:00
# Downloading msoffcrypto_tool-6.0.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.3 MB/s eta 0:00:00
# Building wheels for collected packages: red-black-tree-mod
#   Building wheel for red-black-tree-mod (setup.py) ... done
#   Created wheel for red-black-tree-mod: filename=red_black_tree_mod-1.22-py3-none-any.whl size=19237 sha256=c544c3847425df551ed584bb16534f30b170477a989c03ce6c9904fb8ab516af
#   Stored in directory: /root/.cache/pip/wheels/f6/0b/c7/2c437dd86730e451859662ab2edf7b0ab1541dcf14f7fb3fd1
# Successfully built red-black-tree-mod
# Installing collected packages: red-black-tree-mod, ebcdic, easygui, docx2txt, compressed-rtf, XlsxWriter, xlrd, speechrecognition, olefile, colorclass, argcomplete, python-pptx, pdfminer-six, msoffcrypto-tool, pcodedmp, oletools, RTFDE, extract-msg, textract
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.2
#     Uninstalling xlrd-2.0.2:
#       Successfully uninstalled xlrd-2.0.2
# Successfully installed RTFDE-0.1.2.2 XlsxWriter-3.2.9 argcomplete-3.6.3 colorclass-2.2.2 compressed-rtf-1.0.7 docx2txt-0.9 easygui-0.98.3 ebcdic-1.1.1 extract-msg-0.55.0 msoffcrypto-tool-6.0.0 olefile-0.47 oletools-0.60.2 pcodedmp-1.2.6 pdfminer-six-20260107 python-pptx-1.0.2 red-black-tree-mod-1.22 speechrecognition-3.16.1 textract-2.0.0 xlrd-1.2.0

# %%
import textract

text = textract.process("download.jpg")
print(text.decode("utf-8"))
# Out:
# Jane Doe
#
# 123 Main Street
# Besttown, CA 12345
# (123) 456-7899
# jane.doe@email.com
#
# Product Manager
# Acme Corporation

# %%
# %pip install rapidocr-onnxruntime
# Out:
# Collecting rapidocr-onnxruntime
#   Downloading rapidocr_onnxruntime-1.4.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyclipper>=1.2.0 (from rapidocr-onnxruntime)
#   Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: opencv-python>=4.5.1.48 in /usr/local/lib/python3.12/dist-packages (from rapidocr-onnxruntime) (4.13.0.92)
# Requirement already satisfied: numpy<3.0.0,>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from rapidocr-onnxruntime) (2.0.2)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from rapidocr-onnxruntime) (1.17.0)
# Requirement already satisfied: Shapely!=2.0.4,>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from rapidocr-onnxruntime) (2.1.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from rapidocr-onnxruntime) (6.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rapidocr-onnxruntime) (11.3.0)
# Collecting onnxruntime>=1.7.0 (from rapidocr-onnxruntime)
#   Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from rapidocr-onnxruntime) (4.67.3)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.7.0->rapidocr-onnxruntime) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.7.0->rapidocr-onnxruntime) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.7.0->rapidocr-onnxruntime) (5.29.6)
# Downloading rapidocr_onnxruntime-1.4.4-py3-none-any.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 65.9 MB/s eta 0:00:00
# Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 64.6 MB/s eta 0:00:00
# Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 39.9 MB/s eta 0:00:00
# Installing collected packages: pyclipper, onnxruntime, rapidocr-onnxruntime
# Successfully installed onnxruntime-1.26.0 pyclipper-1.4.0 rapidocr-onnxruntime-1.4.4

# %%
from rapidocr_onnxruntime import RapidOCR

engine = RapidOCR()
result, _ = engine("data.jpg")

for item in result:
    print(item[1])
# Out:
# The language of the moment
# or, as it were, the language of
# the order in which we live, is
# the image. I felt that if I
# wanted to commune with the
# public, I should best do so
# through the language of
# image. It's a conscious
# embraceof acontradiction.
# Godfrey Reggio
# PICTUREQUOTES
# PICTUREQUTES

# %%
# %pip install python-doctr
# Out:
# Collecting python-doctr
#   Downloading python_doctr-1.0.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (2.11.0+cpu)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (0.26.0+cpu)
# Collecting onnx<3.0.0,>=1.12.0 (from python-doctr)
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (2.0.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (1.16.3)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (3.16.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (4.13.0.92)
# Collecting pypdfium2<6.0.0,>=4.11.0 (from python-doctr)
#   Downloading pypdfium2-5.9.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (1.4.0)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (2.1.2)
# Collecting langdetect<2.0.0,>=1.0.9 (from python-doctr)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from python-doctr)
#   Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (1.16.1)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (11.3.0)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (0.7.1)
# Collecting anyascii>=0.3.2 (from python-doctr)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting validators>=0.18.0 (from python-doctr)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from python-doctr) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (6.0.3)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0.0,>=0.20.0->python-doctr) (4.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr) (1.17.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr) (5.29.6)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr) (0.5.4)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr) (3.1.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (3.15)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->python-doctr) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->python-doctr) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=0.20.0->python-doctr) (0.1.2)
# Downloading python_doctr-1.0.1-py3-none-any.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.9/288.9 kB 17.3 MB/s eta 0:00:00
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 24.6 MB/s eta 0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 63.0 MB/s eta 0:00:00
# Downloading pypdfium2-5.9.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 69.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 66.7 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=f2c4b643cac25042ad135fbc5d25f20110d893639fd7c8036b21047d35de0512
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: validators, rapidfuzz, pypdfium2, langdetect, anyascii, onnx, python-doctr
# Successfully installed anyascii-0.3.3 langdetect-1.0.9 onnx-1.21.0 pypdfium2-5.9.0 python-doctr-1.0.1 rapidfuzz-3.14.5 validators-0.35.0

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

doc = DocumentFile.from_images("data.jpg")
model = ocr_predictor(pretrained=True)

result = model(doc)
print(result.render())
# Out:
# Downloading https://doctr-static.mindee.com/models?id=v0.8.1/fast_base-688a8b34.pt&src=0 to /root/.cache/doctr/models/fast_base-688a8b34.pt
#   0%|          | 0/65814772 [00:00<?, ?it/s]
# Downloading https://doctr-static.mindee.com/models?id=v0.12.0/crnn_vgg16_bn-0417f351.pt&src=0 to /root/.cache/doctr/models/crnn_vgg16_bn-0417f351.pt
#   0%|          | 0/63303144 [00:00<?, ?it/s]
# The language ofthe moment
# or, as it were, the language of
# the order in -
# which we live, 1S
# the image.. I felt that ifI
# wanted to commune with the
# public, I should best do SO
# through the language of
# image. It's a conscious
# embrace ofa contradiction.
# Godfrey Reggio
# PICTUREQUOTES.com
# PICTUREQU' TES
